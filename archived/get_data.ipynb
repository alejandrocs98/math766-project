# %% [markdown]
# https://waldronlab.io/curatedMetagenomicData/articles/curatedMetagenomicData.html

# %%
library(tidyverse)
library(DT)
library(data.table)
library(ExperimentHub)
library(curatedMetagenomicData)
hub <- ExperimentHub(cache = "/hpc/group/venturellilab/ac931/.cache/ExperimentHub")
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
# Loading required package: AnnotationHub
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# ...

# %%
# pathabundance_relab
file_name <- "HMP_2012.genefamilies_relab.stool"
data <- curatedMetagenomicData(x = file_name, dryrun = FALSE) %>%
    mergeData() %>%
    as.data.frame()
fwrite(data, file = paste0("data/", file_name, ".csv"))
# Out:
# Working on ZellerG_2014.genefamilies_relab.stool
# Using temporary cache /tmp/RtmpmcUqMY/BiocFileCache
# snapshotDate(): 2019-10-22
# Using temporary cache /tmp/RtmpmcUqMY/BiocFileCache
# Using temporary cache /tmp/RtmpmcUqMY/BiocFileCache
# Using temporary cache /tmp/RtmpmcUqMY/BiocFileCache
# see ?curatedMetagenomicData and browseVignettes('curatedMetagenomicData') for documentation
# Using temporary cache /tmp/RtmpmcUqMY/BiocFileCache
# Using temporary cache /tmp/RtmpmcUqMY/BiocFileCache
# downloading 1 resources
# retrieving 1 resource
# Using temporary cache /tmp/RtmpmcUqMY/BiocFileCache
# loading from cache
# Using temporary cache /tmp/RtmpmcUqMY/BiocFileCache
# Using temporary cache /tmp/RtmpmcUqMY/BiocFileCache
# Using temporary cache /tmp/RtmpmcUqMY/BiocFileCache
